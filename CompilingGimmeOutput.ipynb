# %% [markdown]
# ## Fun with the GIMME Spreadsheets

# %%
# Import the necessary packages. 

import xlrd
import xlwt
import csv

import pandas as pd
import numpy as np

# %%
test = csv.reader('output_subgroup_010819/summaryFit.csv', dialect='excel')

# %%
with open('output_subgroup_010819/summaryFit.csv', newline='') as csvfile:
...     spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
...     for row in spamreader:
...         print(', '.join(row))
# Out:
# "file","chisq","df","npar","pvalue","rmsea","srmr","nnfi","cfi","bic","aic","logl","status","sub_membership","modularity"
# "csm14aff10001_00699",337.464,215,219,0,0.0493,0.0498,0.9468,0.9698,15670.0356,14913.3203,-7237.6601,"converged, normally",2,"0.0163"
# "csm14aff10002_00717",460.4917,232,202,0,0.0649,0.0434,0.919,0.9503,15154.1476,14456.1727,-7026.0864,"converged, normally",1,""
# "csm14aff10004_00747",442.6814,227,207,0,0.0637,0.0493,0.9176,0.9505,15401.1965,14685.945,-7135.9725,"converged, normally",1,""
# "csm14aff10005_00754",369.3483,230,204,0,0.0509,0.0497,0.9395,0.9632,15885.3497,15180.4642,-7386.2321,"converged, normally",1,""
# "csm14aff10006_00780",356.2464,224,210,0,0.0502,0.0499,0.9424,0.9658,15818.3894,15092.7719,-7336.386,"converged, normally",1,""
# "csm14aff10007_00784",422.89,230,204,0,0.0599,0.0472,0.9367,0.9615,14715.7375,14010.852,-6801.426,"converged, normally",1,""
# ...

# %% [markdown]
# The section fo code above will read in a csv file and print out all of the rows.

# %%
#filename = 'output_subgroup_010819/indivPathEstimates.csv'
filename = 'indivPathEstimates.csv'
data = pd.read_csv(filename, header=0)

# %%
print(data)
# Out:
#                       file   dv      iv      beta        se          z  \
# 0      csm14aff10001_00699   V1   V1lag  0.212195  0.059657   3.556949
# 1      csm14aff10001_00699   V2   V2lag  0.249185  0.054616   4.562480
# 2      csm14aff10001_00699   V3   V3lag  0.505449  0.070851   7.133943
# 3      csm14aff10001_00699   V4   V4lag -0.102642  0.056238  -1.825151
# 4      csm14aff10001_00699   V5   V5lag  0.200925  0.055786   3.601682
# 5      csm14aff10001_00699   V6   V6lag  0.167021  0.080392   2.077574
# 6      csm14aff10001_00699   V7   V7lag  0.047824  0.059380   0.805385
# 7      csm14aff10001_00699   V8   V8lag  0.072488  0.061492   1.178823
# 8      csm14aff10001_00699   V9   V9lag  0.046993  0.050605   0.928627
# 9      csm14aff10001_00699  V10  V10lag  0.255029  0.055252   4.615772
# 10     csm14aff10001_00699  V11  V11lag  0.501411  0.051479   9.740142
# 11     csm14aff10001_00699  V12  V12lag  0.330177  0.058438   5.650003
# ...

# %%
V7_V14 = data.loc[(data['dv'] == 'V7') & (data['iv'] == 'V14')]

# %%
print(V7_V14)
# Out:
#                       file  dv   iv      beta        se          z  \
# 14     csm14aff10001_00699  V7  V14  0.886384  0.025364  34.945975
# 86     csm14aff10002_00717  V7  V14  0.961692  0.023661  40.644553
# 141    csm14aff10004_00747  V7  V14  0.937984  0.017545  53.461358
# 201    csm14aff10005_00754  V7  V14  0.574813  0.076335   7.530160
# 258    csm14aff10006_00780  V7  V14  0.878253  0.021173  41.479926
# 321    csm14aff10007_00784  V7  V14  0.893176  0.033646  26.546174
# 378    csm14aff10008_00794  V7  V14  0.660623  0.034287  19.267596
# 437    csm14aff10009_00813  V7  V14  0.931088  0.024200  38.475388
# 495    csm14aff10012_00835  V7  V14  0.820159  0.032489  25.244102
# 554    csm14aff10013_00840  V7  V14  0.948267  0.017428  54.411848
# 619    csm14aff10016_00871  V7  V14  0.730673  0.028807  25.364511
# 677    csm14aff10019_00903  V7  V14  0.812370  0.024423  33.262341
# 746    csm14aff10020_00911  V7  V14  0.847444  0.025635  33.058545
# ...

# %%
V7_V14.to_csv('V7_pred_V14_group.csv', sep=',')

# %%
V4_V11 = data.loc[(data['dv'] == 'V4') & (data['iv'] == 'V11')]

# %%
V4_V11.to_csv('V4_pred_V11_group.csv', sep = ',')

# %%
V8_V1 = data.loc[(data['dv'] == 'V8') & (data['iv'] == 'V1')]

# %%
V8_V1.to_csv('V8_pred_V1_group.csv', sep = ',')

# %%
V5_V12 = data.loc[(data['dv'] == 'V5') & (data['iv'] == 'V12')]

# %%
V5_V12.to_csv('V5_pred_V12_group.csv', sep = ',')

# %%
V6_V7 = data.loc[(data['dv'] == 'V6') & (data['iv'] == 'V7')]
V6_V7.to_csv('V6_pred_V7_group.csv', sep = ',')

# %%
V2_V7 = data.loc[(data['dv'] == 'V2') & (data['iv'] == 'V7')]
V2_V7.to_csv('V2_pred_V7_group.csv', sep = ',')

# %%
V9_V4 = data.loc[(data['dv'] == 'V9') & (data['iv'] == 'V4')]
V9_V4.to_csv('V9_pred_V4_group.csv', sep = ',')

# %%
V13_V6 = data.loc[(data['dv'] == 'V13') & (data['iv'] == 'V6')]
V13_V6.to_csv('V13_pred_V6_group.csv', sep = ',')

# %%
V2_V9 = data.loc[(data['dv'] == 'V2') & (data['iv'] == 'V9')]
V2_V9.to_csv('V2_pred_V9_group.csv', sep = ',')

# %%
V11_V7 = data.loc[(data['dv'] == 'V11') & (data['iv'] == 'V7')]
V11_V7.to_csv('V11_pred_V7_group.csv', sep = ',')

# %%
V13_V14 = data.loc[(data['dv'] == 'V13') & (data['iv'] == 'V14')]
V13_V14.to_csv('V13_pred_V14_group.csv', sep = ',')

# %%
V7_V12 = data.loc[(data['dv'] == 'V7') & (data['iv'] == 'V12')]
V7_V12.to_csv('V7_pred_V12_group.csv', sep = ',')

# %%
V5_V7 = data.loc[(data['dv'] == 'V5') & (data['iv'] == 'V7')]
V5_V7.to_csv('V5_pred_V7_group.csv', sep = ',')

# %%
V3_V4 = data.loc[(data['dv'] == 'V3') & (data['iv'] == 'V4')]
V3_V4.to_csv('V3_pred_V4_group.csv', sep = ',')

# %%
V10_V11 = data.loc[(data['dv'] == 'V10') & (data['iv'] == 'V11')]
V10_V11.to_csv('V10_pred_V11_group.csv', sep = ',')

# %%
V8_V11 = data.loc[(data['dv'] == 'V8') & (data['iv'] == 'V11')]
V8_V11.to_csv('V8_pred_V11_group.csv', sep = ',')

# %%
V6_V9 = data.loc[(data['dv'] == 'V6') & (data['iv'] == 'V9')]
V6_V9.to_csv('V6_pred_V9_group.csv', sep = ',')

# %%
V10_V3 = data.loc[(data['dv'] == 'V10') & (data['iv'] == 'V3')]
V10_V3.to_csv('V10_pred_V3_group.csv', sep = ',')

# %%
V9_V5 = data.loc[(data['dv'] == 'V9') & (data['iv'] == 'V5')]
V9_V5.to_csv('V9_pred_V5_group.csv', sep = ',')

# %% [markdown]
# #### Trying to get at individual level results

# %%
import numpy as np

# %%
sublist = data.file

# %%
sublist_unique = np.unique(sublist)

# %%
for sub in sublist_unique :
    print(sub)
# Out:
# csm14aff10001_00699
# csm14aff10002_00717
# csm14aff10004_00747
# csm14aff10005_00754
# csm14aff10006_00780
# csm14aff10007_00784
# csm14aff10008_00794
# csm14aff10009_00813
# csm14aff10012_00835
# csm14aff10013_00840
# csm14aff10016_00871
# csm14aff10019_00903
# csm14aff10020_00911
# csm14aff10021_00928
# csm14aff10023_00940
# csm14aff10024_00953
# csm14aff10025_00968
# csm14aff10026_00975
# csm14aff10029_00980
# csm14aff10030_00998
# csm14aff10031_01018
# csm14aff10032_01019
# csm14aff10034_01048
# csm14aff10035_01049
# csm14aff10036_01053
# csm14aff10037_01054
# csm14aff10038_01058
# csm14aff10039_01059
# csm14aff10040_01066
# csm14aff10041_01079
# csm14aff10043_01095
# csm14aff10047_01129
# csm14aff10048_01221
# csm14aff10049_01222
# csm14aff10050_01224
# csm14aff10051_01229
# csm14aff10052_01236
# csm14aff10053_01240
# csm14aff10054_01247
# csm14aff10055_01254
# csm14aff10056_01259
# csm14aff10057_01260
# csm14aff10059_01283
# csm14aff10060_01284
# csm14aff10062_01353
# ...

# %%
SN_vars = ['V4','V11','V1','V8','V2','V9','V3','V10']
DMN_vars = ['V5','V12','V7','V14','V6','V13']

# %%
Within_SN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(SN_vars) & data['dv'].isin(SN_vars)]
    cons = len(list1)
    Within_SN_Connections.append({'id': sub, 'SN Connections': cons})

# %%
Within_SN = pd.DataFrame(Within_SN_Connections)
Within_SN.to_csv('Within_SN_Connections_012119.csv')

# %%
Within_DMN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(DMN_vars) & data['dv'].isin(DMN_vars)]
    cons = len(list1)
    Within_DMN_Connections.append({'id': sub, 'DMN Connections': cons})

# %%
Within_DMN = pd.DataFrame(Within_DMN_Connections)
Within_DMN.to_csv('Within_DMN_Connections_012119.csv')

# %%
Btwn_DMN_SN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(DMN_vars) & data['dv'].isin(SN_vars)]
    cons = len(list1)
    Btwn_DMN_SN_Connections.append({'id': sub, 'DMN IV SN DV Connections': cons})

# %%
Btwn_DMN_SN = pd.DataFrame(Btwn_DMN_SN_Connections)
Btwn_DMN_SN.to_csv('Btwn_DMN_SN_Connections_012119.csv')

# %%
Btwn_SN_DMN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(SN_vars) & data['dv'].isin(DMN_vars)]
    cons = len(list1)
    Btwn_SN_DMN_Connections.append({'id': sub, 'SN IV DMN DV Connections': cons})

# %%
Btwn_SN_DMN = pd.DataFrame(Btwn_SN_DMN_Connections)
Btwn_SN_DMN.to_csv('Btwn_SN_DMN_Connections_012119.csv')

# %% [markdown]
# ### Working on some QC Metrics

# %%
data = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/data_113018/csm14aff10001_00699.txt', header = None, sep="\t", names = ["L_Amygdala", "L_dACC", "L_dlPFC", "L_Insula", "L_IPL", "L_MTG", "L_PCC", "R_Amygdala", "R_dACC", "R_dlPFC", "R_Insula", "R_IPL", "R_MTG", "R_PCC"])

# %%
dvars = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/Subjects/csm14aff10001_00699/feat_1.feat/outfinal.feat/motion_outliers_metric_dvars_012819.txt', header = None, sep="\t", names = ["dvars"])

# %%
print(data)
# Out:
#       L_Amygdala       L_dACC      L_dlPFC     L_Insula        L_IPL  \
# 0    6608.415843  11486.01526  10985.35612  8898.195513  15089.33182
# 1    6607.668222  11504.66342  10974.91529  8861.621311  15095.62029
# 2    6602.251026  11503.68695  10973.24718  8870.241129  15087.48213
# 3    6627.296702  11492.94321  10978.26314  8861.618076  15086.62191
# 4    6604.494870  11505.07915  10952.26904  8880.211802  15040.88907
# 5    6593.811919  11527.41511  10944.99258  8867.469585  15040.79972
# 6    6584.611464  11532.51490  10904.72775  8850.942383  15005.46201
# 7    6593.903370  11527.65919  10979.81966  8881.140619  15053.12072
# 8    6596.256681  11531.66171  11007.04397  8913.049334  15028.29225
# 9    6615.978670  11525.84354  10974.68159  8891.659680  15040.86274
# 10   6607.071394  11541.07679  10995.74455  8897.752836  15054.57849
# 11   6605.838657  11494.87367  11023.06829  8912.282256  15083.71198
# 12   6613.120587  11514.57541  11010.21993  8903.244494  15044.58275
# ...

# %%
print(dvars)
# Out:
#            0
# 0     0.0000
# 1    21.7387
# 2    22.8741
# 3    22.6223
# 4    22.3868
# 5    23.9777
# 6    22.6634
# 7    22.9258
# 8    24.5712
# 9    23.0726
# 10   19.6465
# 11   21.2491
# 12   21.4215
# 13   22.5218
# 14   20.5229
# 15   19.7586
# 16   20.9893
# 17   22.2878
# 18   22.7360
# 19   23.8312
# 20   22.7628
# 21   23.7108
# 22   25.5382
# 23   23.7376
# 24   22.6909
# 25   22.0615
# 26   24.6783
# 27   24.2275
# 28   20.8965
# 29   20.5717
# ..       ...
# 205  18.2051
# 206  21.5051
# 207  21.2318
# 208  20.8324
# 209  22.1717
# 210  26.9709
# 211  27.4403
# 212  21.1951
# 213  21.4447
# 214  22.7668
# 215  23.3478
# 216  22.3205
# 217  21.5244
# 218  22.6570
# 219  21.4149
# 220  21.8075
# 221  22.4601
# 222  23.2051
# 223  20.6083
# 224  19.6055
# 225  22.1721
# 226  20.5282
# 227  21.4838
# 228  21.5952
# 229  21.9914
# 230  23.4730
# 231  20.6138
# 232  21.4179
# 233  24.1012
# 234  23.7533
#
# [235 rows x 1 columns]

# %%
frames = [dvars, data]
result = pd.concat(frames, axis=1, join="inner")

# %%
print(result)
# Out:
#        dvars   L_Amygdala       L_dACC      L_dlPFC     L_Insula        L_IPL  \
# 0     0.0000  6608.415843  11486.01526  10985.35612  8898.195513  15089.33182
# 1    21.7387  6607.668222  11504.66342  10974.91529  8861.621311  15095.62029
# 2    22.8741  6602.251026  11503.68695  10973.24718  8870.241129  15087.48213
# 3    22.6223  6627.296702  11492.94321  10978.26314  8861.618076  15086.62191
# 4    22.3868  6604.494870  11505.07915  10952.26904  8880.211802  15040.88907
# 5    23.9777  6593.811919  11527.41511  10944.99258  8867.469585  15040.79972
# 6    22.6634  6584.611464  11532.51490  10904.72775  8850.942383  15005.46201
# 7    22.9258  6593.903370  11527.65919  10979.81966  8881.140619  15053.12072
# 8    24.5712  6596.256681  11531.66171  11007.04397  8913.049334  15028.29225
# 9    23.0726  6615.978670  11525.84354  10974.68159  8891.659680  15040.86274
# 10   19.6465  6607.071394  11541.07679  10995.74455  8897.752836  15054.57849
# ...

# %%
corr = result.corr(method='pearson')

# %%
print(corr)
# Out:
#                dvars  L_Amygdala    L_dACC   L_dlPFC  L_Insula     L_IPL  \
# dvars       1.000000    0.024042  0.002796 -0.044048 -0.034565 -0.046558
# L_Amygdala  0.024042    1.000000  0.171592 -0.210143  0.147761 -0.144308
# L_dACC      0.002796    0.171592  1.000000  0.050375  0.312148 -0.289627
# L_dlPFC    -0.044048   -0.210143  0.050375  1.000000  0.264691  0.393857
# L_Insula   -0.034565    0.147761  0.312148  0.264691  1.000000 -0.209741
# L_IPL      -0.046558   -0.144308 -0.289627  0.393857 -0.209741  1.000000
# L_MTG      -0.013262    0.029978  0.219734  0.383654  0.056171 -0.101773
# L_PCC       0.078239   -0.104077  0.313210  0.475519 -0.083888 -0.027399
# R_Amygdala -0.166729    0.332480  0.089321 -0.144200 -0.145547 -0.071255
# R_dACC     -0.020853    0.218642  0.212217 -0.283419  0.452013 -0.426439
# R_dlPFC    -0.139398    0.019061 -0.335660 -0.083521  0.055265 -0.064051
# R_Insula   -0.083067    0.100614  0.265363 -0.022295  0.679199 -0.371189
# ...

# %%
print(corr.iloc[0])
# Out:
# dvars         1.000000
# L_Amygdala    0.024042
# L_dACC        0.002796
# L_dlPFC      -0.044048
# L_Insula     -0.034565
# L_IPL        -0.046558
# L_MTG        -0.013262
# L_PCC         0.078239
# R_Amygdala   -0.166729
# R_dACC       -0.020853
# R_dlPFC      -0.139398
# R_Insula     -0.083067
# R_IPL        -0.002053
# R_MTG         0.077618
# R_PCC         0.079723
# Name: dvars, dtype: float64

# %%
test = pd.DataFrame(corr.iloc[0])

# %%
print(test)
# Out:
#                dvars
# dvars       1.000000
# L_Amygdala  0.024042
# L_dACC      0.002796
# L_dlPFC    -0.044048
# L_Insula   -0.034565
# L_IPL      -0.046558
# L_MTG      -0.013262
# L_PCC       0.078239
# R_Amygdala -0.166729
# R_dACC     -0.020853
# R_dlPFC    -0.139398
# R_Insula   -0.083067
# R_IPL      -0.002053
# R_MTG       0.077618
# R_PCC       0.079723

# %%
test2  = test.transpose()

# %%
print(test2)
# Out:
#        dvars  L_Amygdala    L_dACC   L_dlPFC  L_Insula     L_IPL     L_MTG  \
# dvars    1.0    0.024042  0.002796 -0.044048 -0.034565 -0.046558 -0.013262
#
#           L_PCC  R_Amygdala    R_dACC   R_dlPFC  R_Insula     R_IPL     R_MTG  \
# dvars  0.078239   -0.166729 -0.020853 -0.139398 -0.083067 -0.002053  0.077618
#
#           R_PCC
# dvars  0.079723

# %%
corrss = test2

# %%
dvars_corrs = pd.DataFrame()

# %%
dvars_corrs.append(corrss[:])
# Out:
#        dvars  L_Amygdala    L_dACC   L_dlPFC  L_Insula     L_IPL     L_MTG  \
# dvars    1.0    0.024042  0.002796 -0.044048 -0.034565 -0.046558 -0.013262
#
#           L_PCC  R_Amygdala    R_dACC   R_dlPFC  R_Insula     R_IPL     R_MTG  \
# dvars  0.078239   -0.166729 -0.020853 -0.139398 -0.083067 -0.002053  0.077618
#
#           R_PCC
# dvars  0.079723

# %%
print(dvars_corrs)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(5):
    dvars_corrs.append(corrss)

# %%
print(dvars_corrs)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for sub in sublist_unique :
    print(sub)
    data = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/data_113018/'+ sub + '.txt', header = None, sep="\t", names = ["L_Amygdala", "L_dACC", "L_dlPFC", "L_Insula", "L_IPL", "L_MTG", "L_PCC", "R_Amygdala", "R_dACC", "R_dlPFC", "R_Insula", "R_IPL", "R_MTG", "R_PCC"])
    dvars = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/Subjects/' + sub + '/feat_1.feat/outfinal.feat/motion_outliers_metric_dvars_012819.txt', header = None, sep="\t", names = ["dvars"])
    frames = [dvars, data]
    result = pd.concat(frames, axis=1, join="inner")
    corr = result.corr(method='pearson')
    test = pd.DataFrame(corr.iloc[0,:])
    test2 = test.transpose()
    #test2.to_csv('fox/' + sub + '.csv')
    with open('dvar_corrs.csv', 'a') as f:
        test2.to_csv(f, header=False)
# Out:
# csm14aff10001_00699
# csm14aff10002_00717
# csm14aff10004_00747
# csm14aff10005_00754
# csm14aff10006_00780
# csm14aff10007_00784
# csm14aff10008_00794
# csm14aff10009_00813
# csm14aff10012_00835
# csm14aff10013_00840
# csm14aff10016_00871
# csm14aff10019_00903
# csm14aff10020_00911
# csm14aff10021_00928
# csm14aff10023_00940
# csm14aff10024_00953
# csm14aff10025_00968
# csm14aff10026_00975
# csm14aff10029_00980
# csm14aff10030_00998
# csm14aff10031_01018
# csm14aff10032_01019
# csm14aff10034_01048
# csm14aff10035_01049
# csm14aff10036_01053
# csm14aff10037_01054
# csm14aff10038_01058
# csm14aff10039_01059
# csm14aff10040_01066
# csm14aff10041_01079
# csm14aff10043_01095
# csm14aff10047_01129
# csm14aff10048_01221
# csm14aff10049_01222
# csm14aff10050_01224
# csm14aff10051_01229
# csm14aff10052_01236
# csm14aff10053_01240
# csm14aff10054_01247
# csm14aff10055_01254
# csm14aff10056_01259
# csm14aff10057_01260
# csm14aff10059_01283
# csm14aff10060_01284
# csm14aff10062_01353
# ...

# %% [markdown]
# #### Incorporating MCFLIRT motion params

# %%
filename = ('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/Subjects/csm14aff10001_00699/feat_1.feat/mc/prefiltered_func_data_mcf.par')

# %%
MC_motion = pd.read_csv(filename, header = None, delimiter="  ", names = ["X","Y","Z","Roll","Pitch","Yaw"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
sub = 'csm14aff10001_00699'

# %%
data = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/data_113018/'+ sub + '.txt', header = None, sep="\t")

# %%
MC_motion = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/Subjects/' + sub + '/feat_1.feat/mc/prefiltered_func_data_mcf.par', header = None, delimiter="  ")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
frames = [data, MC_motion]

# %%
result = pd.concat(frames, axis=1, join="inner")

# %%
print(result)
# Out:
#               0            1            2            3            4   \
# 0    6608.415843  11486.01526  10985.35612  8898.195513  15089.33182
# 1    6607.668222  11504.66342  10974.91529  8861.621311  15095.62029
# 2    6602.251026  11503.68695  10973.24718  8870.241129  15087.48213
# 3    6627.296702  11492.94321  10978.26314  8861.618076  15086.62191
# 4    6604.494870  11505.07915  10952.26904  8880.211802  15040.88907
# 5    6593.811919  11527.41511  10944.99258  8867.469585  15040.79972
# 6    6584.611464  11532.51490  10904.72775  8850.942383  15005.46201
# 7    6593.903370  11527.65919  10979.81966  8881.140619  15053.12072
# 8    6596.256681  11531.66171  11007.04397  8913.049334  15028.29225
# 9    6615.978670  11525.84354  10974.68159  8891.659680  15040.86274
# 10   6607.071394  11541.07679  10995.74455  8897.752836  15054.57849
# 11   6605.838657  11494.87367  11023.06829  8912.282256  15083.71198
# 12   6613.120587  11514.57541  11010.21993  8903.244494  15044.58275
# ...

# %%
corr = result.corr(method='pearson')

# %%
corr_frame = pd.DataFrame(corr.iloc[0:14, 14:20])

# %%
print(corr_frame)
# Out:
#            0         1         2         3         4         5
# 0   0.033013 -0.032009 -0.115853 -0.040481 -0.030307  0.096102
# 1   0.066859  0.118544 -0.111503 -0.039358 -0.218870  0.146730
# 2  -0.128238  0.013288 -0.081069 -0.085472 -0.268292  0.079211
# 3  -0.045715 -0.054175 -0.031943 -0.086065 -0.447646  0.233431
# 4  -0.058678  0.027720  0.028658 -0.117958  0.038288 -0.068720
# 5   0.091674 -0.028224 -0.165439  0.009554 -0.041847  0.021690
# 6  -0.052861  0.111047 -0.155718  0.021636 -0.083492  0.059334
# 7   0.015329  0.077971 -0.042953  0.071213  0.184436 -0.014660
# 8  -0.014471 -0.074626  0.017883  0.015121 -0.223427  0.108492
# 9  -0.014402 -0.223246  0.072546  0.054819 -0.079720 -0.040551
# 10  0.008323 -0.061295  0.045891  0.078227 -0.354518  0.172411
# 11 -0.041316  0.062860  0.165828  0.095749 -0.118342 -0.034781
# 12 -0.009732  0.064510 -0.072047  0.116761 -0.022879  0.011899
# 13 -0.036598  0.098585 -0.159029  0.071882 -0.016413  0.023727

# %%
for sub in sublist_unique :
    print(sub)
    data = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/data_113018/'+ sub + '.txt', header = None, sep="\t")
    MC_motion = pd.read_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/Subjects/' + sub + '/feat_1.feat/mc/prefiltered_func_data_mcf.par', header = None, delimiter="  ")
    frames = [data, MC_motion]
    result = pd.concat(frames, axis=1, join="inner")
    corr = result.corr(method='pearson')
    corr_frame = pd.DataFrame(corr.iloc[0:14, 14:20])
    corr_frame['Sub'] = sub
    #test = pd.DataFrame(corr.iloc[0,:])
    #test2 = test.transpose()
    #test2.to_csv('fox/' + sub + '.csv')
    #corr_frame.to_csv('MC_Corrs/' + sub + '.csv ', header = ["L_Amygdala", "L_dACC", "L_dlPFC", "L_Insula", "L_IPL", "L_MTG", "L_PCC", "R_Amygdala", "R_dACC", "R_dlPFC", "R_Insula", "R_IPL", "R_MTG", "R_PCC","X","Y","Z","Roll","Pitch","Yaw"])
    with open('MC_corrs.csv','a') as f:
        corr_frame.to_csv(f, header=False)
# Out:
# csm14aff10001_00699
# csm14aff10002_00717
# csm14aff10004_00747
# csm14aff10005_00754
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.
# csm14aff10006_00780
# csm14aff10007_00784
# csm14aff10008_00794
# csm14aff10009_00813
# csm14aff10012_00835
# csm14aff10013_00840
# csm14aff10016_00871
# csm14aff10019_00903
# csm14aff10020_00911
# csm14aff10021_00928
# csm14aff10023_00940
# csm14aff10024_00953
# csm14aff10025_00968
# csm14aff10026_00975
# csm14aff10029_00980
# csm14aff10030_00998
# csm14aff10031_01018
# csm14aff10032_01019
# csm14aff10034_01048
# csm14aff10035_01049
# csm14aff10036_01053
# csm14aff10037_01054
# csm14aff10038_01058
# ...

# %% [markdown]
# ### Trying to get at the concept of "hubbness" in the output data

# %% [markdown]
# So my idea for this metric is to count the number of connections into and out of a specfic variable. What a potential hiccup in this process will be the autoregressives and any other potential lag connections because I'm not able to do a list of variables in the same way that I've done before. I think the best way to solve this would be to include some sort of NOT statement that includes a list of the lag variables? I feel like there's probably a way to use wildcards, but I'd rather be a little over cautious.

# %%
Lag_vars = ['V1lag','V2lag','V3lag','V4lag','V5lag','V6lag','V7lag','V8lag','V9lag','V10lag','V11lag','V12lag','V13lag','V14lag']

# %%
V1_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V1') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V1_IV_Connections.append({'id': sub, 'V1 IV': cons})

# %%
V1_IV_Connections = pd.DataFrame(V1_IV_Connections)
V1_IV_Connections.to_csv('V1_IV_Connections_021519.csv')

# %%
V1_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V1')]
    cons = len(list1)
    V1_DV_Connections.append({'id': sub, 'V1 DV': cons})

# %%
V1_DV_Connections = pd.DataFrame(V1_DV_Connections)
V1_DV_Connections.to_csv('V1_DV_Connections_021519.csv')

# %%
V2_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V2') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V2_IV_Connections.append({'id': sub, 'V2 IV': cons})

    
V2_IV_Connections = pd.DataFrame(V2_IV_Connections)
V2_IV_Connections.to_csv('V2_IV_Connections_021519.csv')

# %%
V2_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V2')]
    cons = len(list1)
    V2_DV_Connections.append({'id': sub, 'V2 DV': cons})
    
V2_DV_Connections = pd.DataFrame(V2_DV_Connections)
V2_DV_Connections.to_csv('V2_DV_Connections_021519.csv')

# %%
V3_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V3') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V3_IV_Connections.append({'id': sub, 'V3 IV': cons})

    
V3_IV_Connections = pd.DataFrame(V3_IV_Connections)
V3_IV_Connections.to_csv('V3_IV_Connections_021519.csv')

# %%
V3_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V3')]
    cons = len(list1)
    V3_DV_Connections.append({'id': sub, 'V3 DV': cons})
    
V3_DV_Connections = pd.DataFrame(V3_DV_Connections)
V3_DV_Connections.to_csv('V3_DV_Connections_021519.csv')

# %%
V4_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V4') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V4_IV_Connections.append({'id': sub, 'V4 IV': cons})

    
V4_IV_Connections = pd.DataFrame(V4_IV_Connections)
V4_IV_Connections.to_csv('V4_IV_Connections_021519.csv')

# %%
V4_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V4')]
    cons = len(list1)
    V4_DV_Connections.append({'id': sub, 'V4 DV': cons})
    
V4_DV_Connections = pd.DataFrame(V4_DV_Connections)
V4_DV_Connections.to_csv('V4_DV_Connections_021519.csv')

# %%
V5_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V5') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V5_IV_Connections.append({'id': sub, 'V5 IV': cons})

    
V5_IV_Connections = pd.DataFrame(V5_IV_Connections)
V5_IV_Connections.to_csv('V5_IV_Connections_021519.csv')

# %%
V5_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V5')]
    cons = len(list1)
    V5_DV_Connections.append({'id': sub, 'V5 DV': cons})
    
V5_DV_Connections = pd.DataFrame(V5_DV_Connections)
V5_DV_Connections.to_csv('V5_DV_Connections_021519.csv')

# %%
V6_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V6') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V6_IV_Connections.append({'id': sub, 'V6 IV': cons})

    
V6_IV_Connections = pd.DataFrame(V6_IV_Connections)
V6_IV_Connections.to_csv('V6_IV_Connections_021519.csv')

# %%
V6_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V6')]
    cons = len(list1)
    V6_DV_Connections.append({'id': sub, 'V6 DV': cons})
    
V6_DV_Connections = pd.DataFrame(V6_DV_Connections)
V6_DV_Connections.to_csv('V6_DV_Connections_021519.csv')

# %%
V7_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V7') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V7_IV_Connections.append({'id': sub, 'V7 IV': cons})

    
V7_IV_Connections = pd.DataFrame(V7_IV_Connections)
V7_IV_Connections.to_csv('V7_IV_Connections_021519.csv')

# %%
V7_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V7')]
    cons = len(list1)
    V7_DV_Connections.append({'id': sub, 'V7 DV': cons})
    
V7_DV_Connections = pd.DataFrame(V7_DV_Connections)
V7_DV_Connections.to_csv('V7_DV_Connections_021519.csv')

# %%
V8_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V8') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V8_IV_Connections.append({'id': sub, 'V8 IV': cons})

    
V8_IV_Connections = pd.DataFrame(V8_IV_Connections)
V8_IV_Connections.to_csv('V8_IV_Connections_021519.csv')

# %%
V8_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V8')]
    cons = len(list1)
    V8_DV_Connections.append({'id': sub, 'V8 DV': cons})
    
V8_DV_Connections = pd.DataFrame(V8_DV_Connections)
V8_DV_Connections.to_csv('V8_DV_Connections_021519.csv')

# %%
V9_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V9') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V9_IV_Connections.append({'id': sub, 'V9 IV': cons})

    
V9_IV_Connections = pd.DataFrame(V9_IV_Connections)
V9_IV_Connections.to_csv('V9_IV_Connections_021519.csv')

# %%
V9_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V9')]
    cons = len(list1)
    V9_DV_Connections.append({'id': sub, 'V9 DV': cons})
    
V9_DV_Connections = pd.DataFrame(V9_DV_Connections)
V9_DV_Connections.to_csv('V9_DV_Connections_021519.csv')

# %%
V10_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V10') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V10_IV_Connections.append({'id': sub, 'V10 IV': cons})

    
V10_IV_Connections = pd.DataFrame(V10_IV_Connections)
V10_IV_Connections.to_csv('V10_IV_Connections_021519.csv')

# %%
V10_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V10')]
    cons = len(list1)
    V10_DV_Connections.append({'id': sub, 'V10 DV': cons})
    
V10_DV_Connections = pd.DataFrame(V10_DV_Connections)
V10_DV_Connections.to_csv('V10_DV_Connections_021519.csv')

# %%
V11_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V11') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V11_IV_Connections.append({'id': sub, 'V11 IV': cons})

    
V11_IV_Connections = pd.DataFrame(V11_IV_Connections)
V11_IV_Connections.to_csv('V11_IV_Connections_021519.csv')

# %%
V11_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V11')]
    cons = len(list1)
    V11_DV_Connections.append({'id': sub, 'V11 DV': cons})
    
V11_DV_Connections = pd.DataFrame(V11_DV_Connections)
V11_DV_Connections.to_csv('V11_DV_Connections_021519.csv')

# %%
V12_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V12') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V12_IV_Connections.append({'id': sub, 'V12 IV': cons})

    
V12_IV_Connections = pd.DataFrame(V12_IV_Connections)
V12_IV_Connections.to_csv('V12_IV_Connections_021519.csv')

# %%
V12_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V12')]
    cons = len(list1)
    V12_DV_Connections.append({'id': sub, 'V12 DV': cons})
    
V12_DV_Connections = pd.DataFrame(V12_DV_Connections)
V12_DV_Connections.to_csv('V12_DV_Connections_021519.csv')

# %%
V13_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V13') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V13_IV_Connections.append({'id': sub, 'V13 IV': cons})

    
V13_IV_Connections = pd.DataFrame(V13_IV_Connections)
V13_IV_Connections.to_csv('V13_IV_Connections_021519.csv')

# %%
V13_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V13')]
    cons = len(list1)
    V13_DV_Connections.append({'id': sub, 'V13 DV': cons})
    
V13_DV_Connections = pd.DataFrame(V13_DV_Connections)
V13_DV_Connections.to_csv('V13_DV_Connections_021519.csv')

# %%
V14_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V14') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V14_IV_Connections.append({'id': sub, 'V14 IV': cons})

    
V14_IV_Connections = pd.DataFrame(V14_IV_Connections)
V14_IV_Connections.to_csv('V14_IV_Connections_021519.csv')

# %%
V14_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V14')]
    cons = len(list1)
    V14_DV_Connections.append({'id': sub, 'V14 DV': cons})
    
V14_DV_Connections = pd.DataFrame(V14_DV_Connections)
V14_DV_Connections.to_csv('V14_DV_Connections_021519.csv')

# %% [markdown]
# ## New Analysis starting 2.20.2019

# %% [markdown]
# Okay, so here's the deal -- AB said that KG found an error in how GIMME subgroups was handling exogenous variables (something that we don't have) in a way that wasn't quite correct. They released a new version of GIMME that should have theoretically fixed that, so we're re-running the algorithm on the same data to make sure that our findings don't change. In this case, our subgroup memberships are exactly the same; however, the group level paths in one subgroup are fewer and there are no subgroup level paths. This occurred in the group that was more heterogeneous anyway, so I'm not sure that it really negatively impacts our story, but it is weird because then our group level paths are different depending on the subgroup, which seems wrong. I emailed AB on 2.20.2019 to see what she makes of the situation.
#
# I am also planning to check to see if and how the path counts change. That is the analysis that can be found below.

# %%
filename = '/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/indivPathEstimates.csv'
data = pd.read_csv(filename, header=0)

# %%
sublist = data.file
sublist_unique = np.unique(sublist)

# %%
SN_vars = ['V4','V11','V1','V8','V2','V9','V3','V10']
DMN_vars = ['V5','V12','V7','V14','V6','V13']

# %%
Within_SN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(SN_vars) & data['dv'].isin(SN_vars)]
    cons = len(list1)
    Within_SN_Connections.append({'id': sub, 'SN Connections': cons})

# %%
Within_SN = pd.DataFrame(Within_SN_Connections)
Within_SN.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/Within_SN_Connections_012119.csv')

# %%
Within_DMN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(DMN_vars) & data['dv'].isin(DMN_vars)]
    cons = len(list1)
    Within_DMN_Connections.append({'id': sub, 'DMN Connections': cons})

# %%
Within_DMN = pd.DataFrame(Within_DMN_Connections)
Within_DMN.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/Within_DMN_Connections_012119.csv')

# %%
Btwn_DMN_SN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(DMN_vars) & data['dv'].isin(SN_vars)]
    cons = len(list1)
    Btwn_DMN_SN_Connections.append({'id': sub, 'DMN IV SN DV Connections': cons})

# %%
Btwn_DMN_SN = pd.DataFrame(Btwn_DMN_SN_Connections)
Btwn_DMN_SN.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/Btwn_DMN_SN_Connections_012119.csv')

# %%
Btwn_SN_DMN_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & data['iv'].isin(SN_vars) & data['dv'].isin(DMN_vars)]
    cons = len(list1)
    Btwn_SN_DMN_Connections.append({'id': sub, 'SN IV DMN DV Connections': cons})

# %%
Btwn_SN_DMN = pd.DataFrame(Btwn_SN_DMN_Connections)
Btwn_SN_DMN.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/Btwn_SN_DMN_Connections_012119.csv')

# %% [markdown]
# #### Getting at Hubbness and Group-Level Beta Estimates in the New Data
#
# Good news! It seems like the data analysis plan is back on schedule -- this is good because when the analysis was acting weird, the SN and DMN connection patterns were totally different. Now that it's back fixed, the results are slightlyd different (meaning that something has definitely been updated), but the overall pattern and story are the same, which is good!
#
# Now that I'm back on track, I'll pick back up with the hubbness analysis and also the group level beta analysis.

# %% [markdown]
# I think what I'll start with are the group level beta estimates. I'll go through the output now and see which connections are still present at the group level that do not involve lag connections. Here is a list of those:
#
# | dv | iv |
# |----|----|
# | V8 | V1 |
# | V10|V11 |
# | V4 | V11|
# | V8 | V11|
# | V5 | V12|
# | V7 | V12|
# | V13| V14|
# | V7 | V14|
# | V10| V3 |
# | V3 | V4 |
# | V9 | V4 |
# | V9 | V5 |
# | V13| V6 |
# | V11| V7 |
# | V2 | V7 |
# | V5 | V7 |
# | V6 | V7 |
# | V2 | V9 |
# | V6 | V9 |

# %%
V1_V8 = data.loc[(data['dv'] == 'V8') & (data['iv'] == 'V1')]
V1_V8.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V1_pred_V8_group.csv', sep = ',')

# %%
V11_V10 = data.loc[(data['dv'] == 'V10') & (data['iv'] == 'V11')]
V11_V10.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V11_pred_V10_group.csv', sep = ',')

# %%
V11_V4 = data.loc[(data['dv'] == 'V4') & (data['iv'] == 'V11')]
V11_V4.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V11_pred_V4_group.csv', sep = ',')

# %%
V11_V8 = data.loc[(data['dv'] == 'V8') & (data['iv'] == 'V11')]
V11_V8.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V11_pred_V8_group.csv', sep = ',')

# %%
V12_V5 = data.loc[(data['dv'] == 'V5') & (data['iv'] == 'V12')]
V12_V5.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V12_pred_V5_group.csv', sep = ',')

# %%
V12_V7 = data.loc[(data['dv'] == 'V7') & (data['iv'] == 'V12')]
V12_V7.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V12_pred_V7_group.csv', sep = ',')

# %%
V14_V13 = data.loc[(data['dv'] == 'V13') & (data['iv'] == 'V14')]
V14_V13.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V14_pred_V13_group.csv', sep = ',')

# %%
V14_V7 = data.loc[(data['dv'] == 'V7') & (data['iv'] == 'V14')]
V14_V7.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V14_pred_V7_group.csv', sep = ',')

# %%
V3_V10 = data.loc[(data['dv'] == 'V10') & (data['iv'] == 'V3')]
V3_V10.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V3_pred_V10_group.csv', sep = ',')

# %%
V4_V3 = data.loc[(data['dv'] == 'V3') & (data['iv'] == 'V4')]
V4_V3.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V4_pred_V3_group.csv', sep = ',')

# %%
V4_V9 = data.loc[(data['dv'] == 'V9') & (data['iv'] == 'V4')]
V4_V9.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V4_pred_V9_group.csv', sep = ',')

# %%
V5_V9 = data.loc[(data['dv'] == 'V9') & (data['iv'] == 'V5')]
V5_V9.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V5_pred_V9_group.csv', sep = ',')

# %%
V6_V13 = data.loc[(data['dv'] == 'V13') & (data['iv'] == 'V6')]
V6_V13.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V6_pred_V13_group.csv', sep = ',')

# %%
V7_V11 = data.loc[(data['dv'] == 'V11') & (data['iv'] == 'V7')]
V7_V11.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V7_pred_V11_group.csv', sep = ',')

# %%
V7_V2 = data.loc[(data['dv'] == 'V2') & (data['iv'] == 'V7')]
V7_V2.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V7_pred_V2_group.csv', sep = ',')

# %%
V7_V5 = data.loc[(data['dv'] == 'V5') & (data['iv'] == 'V7')]
V7_V5.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V7_pred_V5_group.csv', sep = ',')

# %%
V7_V6 = data.loc[(data['dv'] == 'V6') & (data['iv'] == 'V7')]
V7_V6.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V7_pred_V6_group.csv', sep = ',')

# %%
V9_V2 = data.loc[(data['dv'] == 'V2') & (data['iv'] == 'V9')]
V9_V2.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V9_pred_V2_group.csv', sep = ',')

# %%
V9_V6 = data.loc[(data['dv'] == 'V6') & (data['iv'] == 'V9')]
V9_V6.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V9_pred_V6_group.csv', sep = ',')

# %% [markdown]
# Okay, now that the group level connections are done, we'll work on the hub connections (not counting the lagged connections).

# %%
Lag_vars = ['V1lag','V2lag','V3lag','V4lag','V5lag','V6lag','V7lag','V8lag','V9lag','V10lag','V11lag','V12lag','V13lag','V14lag']

# %%
V1_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V1') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V1_IV_Connections.append({'id': sub, 'V1 IV': cons})

# %%
V1_IV_Connections = pd.DataFrame(V1_IV_Connections)
V1_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V1_IV_Connections_021519.csv')

# %%
V1_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V1')]
    cons = len(list1)
    V1_DV_Connections.append({'id': sub, 'V1 DV': cons})

# %%
V1_DV_Connections = pd.DataFrame(V1_DV_Connections)
V1_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V1_DV_Connections_021519.csv')

# %%
V2_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V2') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V2_IV_Connections.append({'id': sub, 'V2 IV': cons})

    
V2_IV_Connections = pd.DataFrame(V2_IV_Connections)
V2_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V2_IV_Connections_021519.csv')

# %%
V2_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V2')]
    cons = len(list1)
    V2_DV_Connections.append({'id': sub, 'V2 DV': cons})
    
V2_DV_Connections = pd.DataFrame(V2_DV_Connections)
V2_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V2_DV_Connections_021519.csv')

# %%
V3_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V3') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V3_IV_Connections.append({'id': sub, 'V3 IV': cons})

    
V3_IV_Connections = pd.DataFrame(V3_IV_Connections)
V3_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V3_IV_Connections_021519.csv')

# %%
V3_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V3')]
    cons = len(list1)
    V3_DV_Connections.append({'id': sub, 'V3 DV': cons})
    
V3_DV_Connections = pd.DataFrame(V3_DV_Connections)
V3_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V3_DV_Connections_021519.csv')

# %%
V4_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V4') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V4_IV_Connections.append({'id': sub, 'V4 IV': cons})

    
V4_IV_Connections = pd.DataFrame(V4_IV_Connections)
V4_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V4_IV_Connections_021519.csv')

# %%
V4_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V4')]
    cons = len(list1)
    V4_DV_Connections.append({'id': sub, 'V4 DV': cons})
    
V4_DV_Connections = pd.DataFrame(V4_DV_Connections)
V4_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V4_DV_Connections_021519.csv')

# %%
V5_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V5') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V5_IV_Connections.append({'id': sub, 'V5 IV': cons})

    
V5_IV_Connections = pd.DataFrame(V5_IV_Connections)
V5_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V5_IV_Connections_021519.csv')

# %%
V5_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V5')]
    cons = len(list1)
    V5_DV_Connections.append({'id': sub, 'V5 DV': cons})
    
V5_DV_Connections = pd.DataFrame(V5_DV_Connections)
V5_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V5_DV_Connections_021519.csv')

# %%
V6_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V6') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V6_IV_Connections.append({'id': sub, 'V6 IV': cons})

    
V6_IV_Connections = pd.DataFrame(V6_IV_Connections)
V6_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V6_IV_Connections_021519.csv')

# %%
V6_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V6')]
    cons = len(list1)
    V6_DV_Connections.append({'id': sub, 'V6 DV': cons})
    
V6_DV_Connections = pd.DataFrame(V6_DV_Connections)
V6_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V6_DV_Connections_021519.csv')

# %%
V7_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V7') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V7_IV_Connections.append({'id': sub, 'V7 IV': cons})

    
V7_IV_Connections = pd.DataFrame(V7_IV_Connections)
V7_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V7_IV_Connections_021519.csv')

# %%
V7_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V7')]
    cons = len(list1)
    V7_DV_Connections.append({'id': sub, 'V7 DV': cons})
    
V7_DV_Connections = pd.DataFrame(V7_DV_Connections)
V7_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V7_DV_Connections_021519.csv')

# %%
V8_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V8') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V8_IV_Connections.append({'id': sub, 'V8 IV': cons})

    
V8_IV_Connections = pd.DataFrame(V8_IV_Connections)
V8_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V8_IV_Connections_021519.csv')

# %%
V8_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V8')]
    cons = len(list1)
    V8_DV_Connections.append({'id': sub, 'V8 DV': cons})
    
V8_DV_Connections = pd.DataFrame(V8_DV_Connections)
V8_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V8_DV_Connections_021519.csv')

# %%
V9_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V9') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V9_IV_Connections.append({'id': sub, 'V9 IV': cons})

    
V9_IV_Connections = pd.DataFrame(V9_IV_Connections)
V9_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V9_IV_Connections_021519.csv')

# %%
V9_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V9')]
    cons = len(list1)
    V9_DV_Connections.append({'id': sub, 'V9 DV': cons})
    
V9_DV_Connections = pd.DataFrame(V9_DV_Connections)
V9_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V9_DV_Connections_021519.csv')

# %%
V10_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V10') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V10_IV_Connections.append({'id': sub, 'V10 IV': cons})

    
V10_IV_Connections = pd.DataFrame(V10_IV_Connections)
V10_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V10_IV_Connections_021519.csv')

# %%
V10_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V10')]
    cons = len(list1)
    V10_DV_Connections.append({'id': sub, 'V10 DV': cons})
    
V10_DV_Connections = pd.DataFrame(V10_DV_Connections)
V10_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V10_DV_Connections_021519.csv')

# %%
V11_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V11') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V11_IV_Connections.append({'id': sub, 'V11 IV': cons})

    
V11_IV_Connections = pd.DataFrame(V11_IV_Connections)
V11_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V11_IV_Connections_021519.csv')

# %%
V11_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V11')]
    cons = len(list1)
    V11_DV_Connections.append({'id': sub, 'V11 DV': cons})
    
V11_DV_Connections = pd.DataFrame(V11_DV_Connections)
V11_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V11_DV_Connections_021519.csv')

# %%
V12_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V12') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V12_IV_Connections.append({'id': sub, 'V12 IV': cons})

    
V12_IV_Connections = pd.DataFrame(V12_IV_Connections)
V12_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V12_IV_Connections_021519.csv')

# %%
V12_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V12')]
    cons = len(list1)
    V12_DV_Connections.append({'id': sub, 'V12 DV': cons})
    
V12_DV_Connections = pd.DataFrame(V12_DV_Connections)
V12_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V12_DV_Connections_021519.csv')

# %%
V13_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V13') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V13_IV_Connections.append({'id': sub, 'V13 IV': cons})

    
V13_IV_Connections = pd.DataFrame(V13_IV_Connections)
V13_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V13_IV_Connections_021519.csv')

# %%
V13_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V13')]
    cons = len(list1)
    V13_DV_Connections.append({'id': sub, 'V13 DV': cons})
    
V13_DV_Connections = pd.DataFrame(V13_DV_Connections)
V13_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V13_DV_Connections_021519.csv')

# %%
V14_IV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & (data['iv'] == 'V14') & ~data['dv'].isin(Lag_vars)]
    cons = len(list1)
    V14_IV_Connections.append({'id': sub, 'V14 IV': cons})

    
V14_IV_Connections = pd.DataFrame(V14_IV_Connections)
V14_IV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V14_IV_Connections_021519.csv')

# %%
V14_DV_Connections = []

for sub in sublist_unique:
    list1 = data.loc[(data['file'] == sub) & ~data['iv'].isin(Lag_vars) & (data['dv'] == 'V14')]
    cons = len(list1)
    V14_DV_Connections.append({'id': sub, 'V14 DV': cons})
    
V14_DV_Connections = pd.DataFrame(V14_DV_Connections)
V14_DV_Connections.to_csv('/Volumes/lsa-csmonk/bbox/FF_Data/Working_Files/Resting/GIMME/output_subgroup_v5.1_linux_022819/V14_DV_Connections_021519.csv')
